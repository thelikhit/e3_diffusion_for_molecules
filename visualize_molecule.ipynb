# %%
from configs.datasets_config import get_dataset_info
from qm9.visualizer import load_molecule_xyz, plot_data3d, visualize_chain_uncertainty
import torch

# %%
def visualize_single_molecule(file, dataset_info, max_num=25, wandb=None, spheres_3d=False):
    positions, one_hot, charges = load_molecule_xyz(file, dataset_info)
    atom_type = torch.argmax(one_hot, dim=1).numpy()
    dists = torch.cdist(positions.unsqueeze(0), positions.unsqueeze(0)).squeeze(0)
    dists = dists[dists > 0]
    print("Average distance between atoms", dists.mean().item())
    plot_data3d(positions, atom_type, dataset_info=dataset_info, save_path=file[:-4] + '.png',
                spheres_3d=spheres_3d)

# %%
dataset_info = get_dataset_info('qm9', False)

files = [
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_000.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_012.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_024.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_036.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_048.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_060.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_072.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_084.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_096.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_109.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_000.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_012.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/chain_0/chain_024.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/baseline_polynomial_3/eval/chain_0/chain_036.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/baseline_polynomial_3/eval/chain_0/chain_048.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/baseline_polynomial_3/eval/chain_0/chain_060.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/baseline_polynomial_3/eval/chain_0/chain_072.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/baseline_polynomial_3/eval/chain_0/chain_084.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/baseline_polynomial_3/eval/chain_0/chain_096.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/baseline_polynomial_3/eval/chain_0/chain_109.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/baseline_polynomial_3/eval/chain_0/chain_000.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/baseline_polynomial_3/eval/chain_0/chain_012.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/baseline_polynomial_3/eval/chain_0/chain_024.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_slowly/eval/chain_0/chain_000.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_slowly/eval/chain_0/chain_012.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_slowly/eval/chain_0/chain_024.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_slowly/eval/chain_0/chain_036.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_slowly/eval/chain_0/chain_048.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_slowly/eval/chain_0/chain_060.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_slowly/eval/chain_0/chain_072.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_slowly/eval/chain_0/chain_084.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_slowly/eval/chain_0/chain_096.txt',
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_slowly/eval/chain_0/chain_109.txt' 
]

# %%
for file in files:
    visualize_single_molecule(file, dataset_info)
# Out:
# Average distance between atoms 2.0099456310272217
# Average distance between atoms 2.1869113445281982
# Average distance between atoms 2.6420528888702393
# Average distance between atoms 2.6939756870269775
# Average distance between atoms 2.6537728309631348
# Average distance between atoms 2.8099424839019775
# Average distance between atoms 2.8104636669158936
# Average distance between atoms 2.7660508155822754
# Average distance between atoms 2.367016077041626
# Average distance between atoms 1.571037769317627
# Average distance between atoms 2.0099456310272217
# Average distance between atoms 2.1869113445281982
# Average distance between atoms 2.6420528888702393
# Average distance between atoms 2.5837645530700684
# Average distance between atoms 2.6363942623138428
# Average distance between atoms 2.6458449363708496
# Average distance between atoms 2.8677449226379395
# Average distance between atoms 3.038773775100708
# Average distance between atoms 3.1460986137390137
# ...

# %%
visualize_chain_uncertainty(
    '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/', dataset_info,
    spheres_3d=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 visualize_chain_uncertainty(
#       2     '/home/vinh/likhit/e3_diffusion_for_molecules/outputs/destroy_input_rapidly/eval/', dataset_info,
#       3     spheres_3d=True)
#
# File ~/likhit/e3_diffusion_for_molecules/qm9/visualizer.py:385, in visualize_chain_uncertainty(path, dataset_info, wandb, spheres_3d, mode)
#     382     save_paths.append(fn)
#     384 imgs = [imageio.imread(fn) for fn in save_paths]
# --> 385 dirname = os.path.dirname(save_paths[0])
#     386 gif_path = dirname + '/output.gif'
#     387 print(f'Creating gif with {len(imgs)} images')
#
# IndexError: list index out of range
